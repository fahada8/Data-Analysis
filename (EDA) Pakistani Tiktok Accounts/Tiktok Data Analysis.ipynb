# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data1 = pd.read_csv('pak_tiktokers.csv')

# %%
data1.sample(15)
# Out:
#                 UserId,Name,Videos,Fans,Views,Account
# 66  https://www.tiktok.com/@mehreenkhokhar1,Momeee...
# 70  https://www.tiktok.com/@sharjeel_awish01,Sharj...
# 76  https://www.tiktok.com/@lalagee786,lalagee786,...
# 64  https://www.tiktok.com/@saifkhan45,Saif Khan,6...
# 89  https://www.tiktok.com/@durdanaeimaan,Dolphin?...
# 28  https://www.tiktok.com/@umereee,Umer,"1,483",4...
# 92  https://www.tiktok.com/@juttbahadr,Jutt bahade...
# 33  https://www.tiktok.com/@paridoll16,paridoll16,...
# 8   https://www.tiktok.com/@areeka__haq,Areeka,"1,...
# 21  https://www.tiktok.com/@romaisa.khan._,Romaisa...
# 78  https://www.tiktok.com/@nimi_ansari,nimra Ansa...
# 50  https://www.tiktok.com/@muhammad_fahad_27,muha...
# 56  https://www.tiktok.com/@najibafaiz,Najiba Faiz...
# 52  https://www.tiktok.com/@meerjangikhanrais,Meer...
# 86  https://www.tiktok.com/@m.momin_mughal44,m.mom...

# %% [markdown]
# # Data Cleaning

# %%
data1 = data1['UserId,Name,Videos,Fans,Views,Account'].str.split(',', expand=True)

# %%
data1.columns = ["0", "1", "2", "3", "4", "5", "6", "7"]

# %%
data1.drop(columns=['2'],axis=1, inplace=True)

# %%
data1
# Out:
#                                             0                    1     3  \
# 0         https://www.tiktok.com/@jannatmirza             J M ????  212"
# 1          https://www.tiktok.com/@kanwal.135         Kanwalay????  039"
# 2     https://www.tiktok.com/@ch.zulqarnain25  Zulqarnain Sikandar  573"
# 3       https://www.tiktok.com/@alishbahanjum               Lishay  238"
# 4       https://www.tiktok.com/@hoormahaveera       Hoor Mahaveera  240"
# ..                                        ...                  ...   ...
# 95         https://www.tiktok.com/@bilaljani5           Chento????  784"
# 96      https://www.tiktok.com/@hammadmalik74        hammadmalik74  745"
# 97  https://www.tiktok.com/@laibakhanofficial           laiba khan  1.8M
# 98     https://www.tiktok.com/@zehraqureshi00                Zehra  885"
# 99       https://www.tiktok.com/@sallubhai223      Salahuddin Khan  885"
#
#          4          5            6            7
# 0    13.6M      2.15B    "Pakistan  2018-03-18"
# 1    11.6M    962.74M    "Pakistan  2018-09-22"
# 2    11.4M      2.15B    "Pakistan  2018-07-20"
# 3    11.2M    751.86M    "Pakistan  2016-06-25"
# 4    10.6M    183.86M    "Pakistan  2017-03-06"
# ..     ...        ...          ...          ...
# 95    1.8M    543.57M    "Pakistan  2018-08-05"
# 96    1.8M    266.38M    "Pakistan  2018-11-06"
# 97  59.98M  "Pakistan  2018-12-06"         None
# 98    1.8M    138.63M    "Pakistan  2019-08-14"
# 99    1.8M    136.19M    "Pakistan  2019-06-29"
#
# [100 rows x 7 columns]

# %%
data1.rename(columns={'0':'User_ID','1':'Name','3':'Videos','4':'Followers','5':'Views','6':'Country','7':'Date_Created'},
             inplace=True)

# %%
data1.sample(10)
# Out:
#                                    User_ID              Name Videos Followers  \
# 31  https://www.tiktok.com/@sunmbalkhangee  Sunmbal Khan Gee   549"      3.7M
# 12    https://www.tiktok.com/@harrisali_01        Harris Ali   530"      5.9M
# 49      https://www.tiktok.com/@rubiali110          Rubi Ali   2.8M   226.28M
# 51   https://www.tiktok.com/@kainat_faisal     kainat Faisal   2.7M   112.15M
# 42   https://www.tiktok.com/@ushab_rajpoot              ????   3.1M   101.38M
# 60    https://www.tiktok.com/@rabiakhan806        rabia Khan   825"      2.5M
# 77     https://www.tiktok.com/@dimple_boys        dimpleboys   500"        2M
# 78     https://www.tiktok.com/@nimi_ansari      nimra Ansari   048"        2M
# 99    https://www.tiktok.com/@sallubhai223   Salahuddin Khan   885"      1.8M
# 81   https://www.tiktok.com/@nayyab_kiani1      Nayyab Kiani   1.9M    15.13M
#
#         Views      Country Date_Created
# 31    544.18M    "Pakistan  2018-02-21"
# 12    801.57M    "Pakistan  2018-07-06"
# 49  "Pakistan  2018-08-09"         None
# 51  "Pakistan  2019-03-09"         None
# 42  "Pakistan  2018-12-11"         None
# 60    120.31M    "Pakistan  2019-10-29"
# 77    270.46M    "Pakistan  2019-06-04"
# 78     173.1M    "Pakistan  2018-12-10"
# 99    136.19M    "Pakistan  2019-06-29"
# 81  "Pakistan  2017-12-23"         None

# %%
data1['User_ID'] = data1['User_ID'].replace({'https://www.tiktok.com/':' '}, regex=True)
data1['Videos'] = data1['Videos'].replace({'"':''}, regex=True)
data1['Country'] = data1['Country'].replace({'"':''}, regex=True)
data1['Date_Created'] = data1['Date_Created'].replace({'"':''},regex=True)

# %%
data1.sample(15)
# Out:
#                    User_ID                     Name Videos Followers  \
# 11                @aalleey               Ali Fayyaz    599      6.5M
# 41                @akhroot               Haris Khan   3.1M    400.6M
# 46       @irfanmuhammad480              محمّد عرفان     3M    53.23M
# 98         @zehraqureshi00                    Zehra    885      1.8M
# 25       @kashees.official        Kashee’s official    760      4.2M
# 99           @sallubhai223          Salahuddin Khan    885      1.8M
# 45           @mishalhearts  MISHAL HEARTS (مشعل بٹ)     3M   345.24M
# 33             @paridoll16               paridoll16    942      3.6M
# 76             @lalagee786               lalagee786    767        2M
# 19               @rabeecak            Rabeecakashif   5.1M    96.64M
# 1              @kanwal.135             Kanwalay????    039     11.6M
# 90   @reallifesuperheroes1      RealLifeSuperHeroes    139      1.9M
# 68           @siddiquiboss      Aman Ullah Siddiqui    686      2.3M
# 37              @marvich95                 Marvi ❤️    352      3.5M
# 71               @laraiblk            Laraib Khalid    437      2.2M
#
#         Views     Country Date_Created
# 11    813.33M    Pakistan   2018-10-01
# 41  "Pakistan  2018-03-23         None
# 46  "Pakistan  2019-07-13         None
# 98    138.63M    Pakistan   2019-08-14
# 25    816.35M    Pakistan   2018-11-07
# 99    136.19M    Pakistan   2019-06-29
# 45  "Pakistan  2018-07-07         None
# 33    744.73M    Pakistan   2018-03-30
# 76    802.34M    Pakistan   2019-04-01
# 19  "Pakistan  2018-08-31         None
# 1     962.74M    Pakistan   2018-09-22
# 90    162.13M    Pakistan   2019-08-18
# 68    331.59M    Pakistan   2018-08-07
# 37     362.1M    Pakistan   2019-03-06
# 71    143.87M    Pakistan   2019-04-26

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   User_ID       100 non-null    object
#  1   Name          100 non-null    object
#  2   Videos        100 non-null    object
#  3   Followers     100 non-null    object
#  4   Views         100 non-null    object
#  5   Country       100 non-null    object
#  6   Date_Created  74 non-null     object
# dtypes: object(7)
# memory usage: 5.6+ KB

# %%
data1.dtypes
# Out:
# User_ID         object
# Name            object
# Videos          object
# Followers       object
# Views           object
# Country         object
# Date_Created    object
# dtype: object

# %%
def value_to_float(x):
    if type(x) == float or type(x) == int:
        return x
    if 'K' in x:
        if len(x) > 1:
            return float(x.replace('K', '')) * 1000
        return 1000.0
    if 'M' in x:
        if len(x) > 1:
            return float(x.replace('M', '')) * 1000000
        return 1000000.0
    if 'B' in x:
        return float(x.replace('B', '')) * 1000000000
    return 1000000000.0

# %%
data1['Followers'] = data1['Followers'].apply(value_to_float)
data1['Views'] = data1['Views'].apply(value_to_float)
data1.sample(20)
# Out:
#                     User_ID                     Name Videos    Followers  \
# 45            @mishalhearts  MISHAL HEARTS (مشعل بٹ)     3M  345240000.0
# 81           @nayyab_kiani1             Nayyab Kiani   1.9M   15130000.0
# 67            @ali_khanking            Ali Khan ????   2.3M  110230000.0
# 92              @juttbahadr             Jutt bahader   1.9M  342600000.0
# 23     @aimanzamanofficia82              aiman zaman    079    4700000.0
# 98          @zehraqureshi00                    Zehra    885    1800000.0
# 93              @schixarana              SchiXa Rana    140    1900000.0
# 22      @zeeshanrokhari6970           Zeeshan Rokhri    030    4700000.0
# 79            @sherryhearts  SHERRY HEARTS (شیری بٹ)    126    2000000.0
# 9    @mehakmalikofficial578     Mehak Malik official    604    7800000.0
# 25        @kashees.official        Kashee’s official    760    4200000.0
# 78             @nimi_ansari             nimra Ansari    048    2000000.0
# 31          @sunmbalkhangee         Sunmbal Khan Gee    549    3700000.0
# 72             @mr_aadi__05         Allauddin Noor M    352    2200000.0
# 21          @romaisa.khan._             Romaisa Khan    041    5000000.0
# 41                 @akhroot               Haris Khan   3.1M  400600000.0
# 10            @sehar_hayyat             Sehar Hayyat    076    7300000.0
# 61             @jalaluddin6              Jalal Uddin    113    2400000.0
# 68            @siddiquiboss      Aman Ullah Siddiqui    686    2300000.0
# 52       @meerjangikhanrais                     Meer   2.7M  250550000.0
#
#            Views     Country Date_Created
# 45  1.000000e+09  2018-07-07         None
# 81  1.000000e+09  2017-12-23         None
# 67  1.000000e+09  2019-01-13         None
# 92  1.000000e+09  2018-12-14         None
# 23  7.603900e+08    Pakistan   2019-11-19
# 98  1.386300e+08    Pakistan   2019-08-14
# 93  1.386400e+08    Pakistan   2019-02-02
# 22  8.950000e+07    Pakistan   2019-07-14
# 79  2.074400e+08    Pakistan   2018-07-08
# 9   1.940000e+09    Pakistan   2019-01-18
# 25  8.163500e+08    Pakistan   2018-11-07
# 78  1.731000e+08    Pakistan   2018-12-10
# 31  5.441800e+08    Pakistan   2018-02-21
# 72  6.040100e+08    Pakistan   2018-10-03
# 21  3.490800e+08    Pakistan   2016-10-18
# 41  1.000000e+09  2018-03-23         None
# 10  2.150000e+09    Pakistan   2018-03-14
# 61  2.928100e+08    Pakistan   2018-07-27
# 68  3.315900e+08    Pakistan   2018-08-07
# 52  1.000000e+09  2018-07-01         None

# %%
data1.sample(15)
# Out:
#                  User_ID                 Name Videos    Followers  \
# 75    @haroonrajofficial           Haroon Raj    038    2100000.0
# 85    @real_umerkaraxhii  Real_@Umer KaraxHii   1.9M  121780000.0
# 98       @zehraqureshi00                Zehra    885    1800000.0
# 47        @alifaisaljutt      Ali Faisal Jutt    281    2900000.0
# 22   @zeeshanrokhari6970       Zeeshan Rokhri    030    4700000.0
# 81        @nayyab_kiani1         Nayyab Kiani   1.9M   15130000.0
# 71             @laraiblk        Laraib Khalid    437    2200000.0
# 18        @hussaintareen       Hussain Tareen    382    5200000.0
# 29         @adeelmurtaza                   AD   3.9M  414100000.0
# 61          @jalaluddin6          Jalal Uddin    113    2400000.0
# 8           @areeka__haq               Areeka    046    8100000.0
# 10         @sehar_hayyat         Sehar Hayyat    076    7300000.0
# 37            @marvich95             Marvi ❤️    352    3500000.0
# 76           @lalagee786           lalagee786    767    2000000.0
# 95           @bilaljani5           Chento????    784    1800000.0
#
#            Views     Country Date_Created
# 75  1.698100e+08    Pakistan   2019-08-28
# 85  1.000000e+09  2017-10-02         None
# 98  1.386300e+08    Pakistan   2019-08-14
# 47  4.882300e+08    Pakistan   2018-12-09
# 22  8.950000e+07    Pakistan   2019-07-14
# 81  1.000000e+09  2017-12-23         None
# 71  1.438700e+08    Pakistan   2019-04-26
# 18  3.323700e+08    Pakistan   2018-05-04
# 29  1.000000e+09  2018-02-14         None
# 61  2.928100e+08    Pakistan   2018-07-27
# 8   1.450000e+09    Pakistan   2018-06-18
# 10  2.150000e+09    Pakistan   2018-03-14
# 37  3.621000e+08    Pakistan   2019-03-06
# 76  8.023400e+08    Pakistan   2019-04-01
# 95  5.435700e+08    Pakistan   2018-08-05

# %%
data2 = data1[data1['Date_Created'].isnull()]
data2
# Out:
#                 User_ID                     Name Videos    Followers  \
# 19            @rabeecak            Rabeecakashif   5.1M   96640000.0
# 24           @aliriaz84         Ali Riaz ♠️ ????   4.4M  182250000.0
# 26        @arooba_khann                   Arooba   4.1M  155340000.0
# 29        @adeelmurtaza                       AD   3.9M  414100000.0
# 39          @basitrind5              Abdul Basit   3.3M  182740000.0
# 41             @akhroot               Haris Khan   3.1M  400600000.0
# 42       @ushab_rajpoot                     ????   3.1M  101380000.0
# 45        @mishalhearts  MISHAL HEARTS (مشعل بٹ)     3M  345240000.0
# 46    @irfanmuhammad480              محمّد عرفان     3M   53230000.0
# 49          @rubiali110                 Rubi Ali   2.8M  226280000.0
# 51       @kainat_faisal            kainat Faisal   2.7M  112150000.0
# 52   @meerjangikhanrais                     Meer   2.7M  250550000.0
# 56          @najibafaiz              Najiba Faiz   2.6M  185850000.0
# 58       @salt_to_taste            Salt to taste   2.5M  172940000.0
# 64          @saifkhan45                Saif Khan   2.4M  176970000.0
# 65         @gulpanra888                Gul Panra   2.4M  165490000.0
# 67        @ali_khanking            Ali Khan ????   2.3M  110230000.0
# 69     @arashayousafzai         Arasha Yousafzai   2.2M   17760000.0
# 73          @asadmaseed                asad khan   2.1M  203390000.0
# 81       @nayyab_kiani1             Nayyab Kiani   1.9M   15130000.0
# 82        @musahussain5             Musa Hussain   1.9M  263810000.0
# 83         @sanabutt660              Sanabutt660   1.9M   87650000.0
# 85   @real_umerkaraxhii      Real_@Umer KaraxHii   1.9M  121780000.0
# 91     @shaheer._.khan1             Shaheer khan   1.9M  199350000.0
# 92          @juttbahadr             Jutt bahader   1.9M  342600000.0
# 97   @laibakhanofficial               laiba khan   1.8M   59980000.0
#
#            Views     Country Date_Created
# 19  1.000000e+09  2018-08-31         None
# 24  1.000000e+09  2019-11-25         None
# 26  1.000000e+09  2018-10-02         None
# 29  1.000000e+09  2018-02-14         None
# 39  1.000000e+09  2018-11-21         None
# 41  1.000000e+09  2018-03-23         None
# 42  1.000000e+09  2018-12-11         None
# 45  1.000000e+09  2018-07-07         None
# 46  1.000000e+09  2019-07-13         None
# 49  1.000000e+09  2018-08-09         None
# 51  1.000000e+09  2019-03-09         None
# 52  1.000000e+09  2018-07-01         None
# 56  1.000000e+09  2018-05-09         None
# 58  1.000000e+09  2019-02-02         None
# 64  1.000000e+09  2018-09-17         None
# 65  1.000000e+09  2019-07-22         None
# 67  1.000000e+09  2019-01-13         None
# 69  1.000000e+09  2019-06-15         None
# 73  1.000000e+09  2019-07-03         None
# 81  1.000000e+09  2017-12-23         None
# 82  1.000000e+09  2019-04-26         None
# 83  1.000000e+09  2018-10-01         None
# 85  1.000000e+09  2017-10-02         None
# 91  1.000000e+09  2019-06-26         None
# 92  1.000000e+09  2018-12-14         None
# 97  1.000000e+09  2018-12-06         None

# %%
data3 = pd.concat([data1,data2])

# %%
data3
# Out:
#                 User_ID                 Name Videos    Followers  \
# 0          @jannatmirza             J M ????    212   13600000.0
# 1           @kanwal.135         Kanwalay????    039   11600000.0
# 2      @ch.zulqarnain25  Zulqarnain Sikandar    573   11400000.0
# 3        @alishbahanjum               Lishay    238   11200000.0
# 4        @hoormahaveera       Hoor Mahaveera    240   10600000.0
# ..                  ...                  ...    ...          ...
# 83         @sanabutt660          Sanabutt660   1.9M   87650000.0
# 85   @real_umerkaraxhii  Real_@Umer KaraxHii   1.9M  121780000.0
# 91     @shaheer._.khan1         Shaheer khan   1.9M  199350000.0
# 92          @juttbahadr         Jutt bahader   1.9M  342600000.0
# 97   @laibakhanofficial           laiba khan   1.8M   59980000.0
#
#            Views     Country Date_Created
# 0   2.150000e+09    Pakistan   2018-03-18
# 1   9.627400e+08    Pakistan   2018-09-22
# 2   2.150000e+09    Pakistan   2018-07-20
# 3   7.518600e+08    Pakistan   2016-06-25
# 4   1.838600e+08    Pakistan   2017-03-06
# ..           ...         ...          ...
# 83  1.000000e+09  2018-10-01         None
# 85  1.000000e+09  2017-10-02         None
# 91  1.000000e+09  2019-06-26         None
# 92  1.000000e+09  2018-12-14         None
# 97  1.000000e+09  2018-12-06         None
#
# [126 rows x 7 columns]

# %%
data1.isnull().sum()
# Out:
# User_ID          0
# Name             0
# Videos           0
# Followers        0
# Views            0
# Country          0
# Date_Created    26
# dtype: int64

# %%
data1.dropna(inplace=True)

# %%
data1.sample(20)
# Out:
#                     User_ID                  Name Videos   Followers  \
# 53            @chabrarahmad        Ch AbrAr AhmAd    210   2600000.0
# 25        @kashees.official     Kashee’s official    760   4200000.0
# 23     @aimanzamanofficia82           aiman zaman    079   4700000.0
# 78             @nimi_ansari          nimra Ansari    048   2000000.0
# 93              @schixarana           SchiXa Rana    140   1900000.0
# 33              @paridoll16            paridoll16    942   3600000.0
# 18           @hussaintareen        Hussain Tareen    382   5200000.0
# 40          @umairchaudhry3        Umair Chaudhry    141   3200000.0
# 5              @usmanasim66           Malik Usman    522  10100000.0
# 59             @wajidali703     Wajid ali Rajpoot    857   2500000.0
# 57           @aqeel1khan556                   A K    317   2600000.0
# 71                @laraiblk         Laraib Khalid    437   2200000.0
# 20        @asadaliofficiall    Asad ali |????????    865   5100000.0
# 44            @wardamalik94           Warda Malik    113   3100000.0
# 90    @reallifesuperheroes1   RealLifeSuperHeroes    139   1900000.0
# 3            @alishbahanjum                Lishay    238  11200000.0
# 87               @_laibiii_                laibii    625   1900000.0
# 9    @mehakmalikofficial578  Mehak Malik official    604   7800000.0
# 15         @asadrayofficial              ASAD RAY    314   5400000.0
# 36               @sofiakaif            Sofia Kaif    015   3500000.0
#
#            Views   Country Date_Created
# 53  3.386300e+08  Pakistan   2019-05-24
# 25  8.163500e+08  Pakistan   2018-11-07
# 23  7.603900e+08  Pakistan   2019-11-19
# 78  1.731000e+08  Pakistan   2018-12-10
# 93  1.386400e+08  Pakistan   2019-02-02
# 33  7.447300e+08  Pakistan   2018-03-30
# 18  3.323700e+08  Pakistan   2018-05-04
# 40  2.965200e+08  Pakistan   2019-03-29
# 5   1.210000e+09  Pakistan   2018-07-10
# 59  4.909200e+08  Pakistan   2018-07-11
# 57  7.251900e+08  Pakistan   2019-06-22
# 71  1.438700e+08  Pakistan   2019-04-26
# 20  3.833000e+08  Pakistan   2019-05-12
# 44  1.421400e+08  Pakistan   2019-05-19
# 90  1.621300e+08  Pakistan   2019-08-18
# 3   7.518600e+08  Pakistan   2016-06-25
# 87  2.339100e+08  Pakistan   2018-08-26
# 9   1.940000e+09  Pakistan   2019-01-18
# 15  5.830000e+08  Pakistan   2018-11-10
# 36  2.218200e+08  Pakistan   2018-05-18

# %%
data3['Videos'] = data1['Videos'].astype(int)
data3['Date_Created'] = pd.to_datetime(data3['Date_Created'])

# %%
data3['Year'] = data3['Date_Created'].dt.year
data3['Month'] = data3['Date_Created'].dt.month

# %%
data3
# Out:
#                 User_ID                 Name  Videos    Followers  \
# 0          @jannatmirza             J M ????   212.0   13600000.0
# 1           @kanwal.135         Kanwalay????    39.0   11600000.0
# 2      @ch.zulqarnain25  Zulqarnain Sikandar   573.0   11400000.0
# 3        @alishbahanjum               Lishay   238.0   11200000.0
# 4        @hoormahaveera       Hoor Mahaveera   240.0   10600000.0
# ..                  ...                  ...     ...          ...
# 83         @sanabutt660          Sanabutt660     NaN   87650000.0
# 85   @real_umerkaraxhii  Real_@Umer KaraxHii     NaN  121780000.0
# 91     @shaheer._.khan1         Shaheer khan     NaN  199350000.0
# 92          @juttbahadr         Jutt bahader     NaN  342600000.0
# 97   @laibakhanofficial           laiba khan     NaN   59980000.0
#
#            Views     Country Date_Created    Year  Month
# 0   2.150000e+09    Pakistan   2018-03-18  2018.0    3.0
# 1   9.627400e+08    Pakistan   2018-09-22  2018.0    9.0
# 2   2.150000e+09    Pakistan   2018-07-20  2018.0    7.0
# 3   7.518600e+08    Pakistan   2016-06-25  2016.0    6.0
# 4   1.838600e+08    Pakistan   2017-03-06  2017.0    3.0
# ..           ...         ...          ...     ...    ...
# 83  1.000000e+09  2018-10-01          NaT     NaN    NaN
# 85  1.000000e+09  2017-10-02          NaT     NaN    NaN
# 91  1.000000e+09  2019-06-26          NaT     NaN    NaN
# 92  1.000000e+09  2018-12-14          NaT     NaN    NaN
# 97  1.000000e+09  2018-12-06          NaT     NaN    NaN
#
# [126 rows x 9 columns]

# %%
data3['Videos'] = data3['Videos'].replace(np.nan, data3['Videos'].mean())

# %%
data3
# Out:
#                 User_ID                 Name     Videos    Followers  \
# 0          @jannatmirza             J M ????  212.00000   13600000.0
# 1           @kanwal.135         Kanwalay????   39.00000   11600000.0
# 2      @ch.zulqarnain25  Zulqarnain Sikandar  573.00000   11400000.0
# 3        @alishbahanjum               Lishay  238.00000   11200000.0
# 4        @hoormahaveera       Hoor Mahaveera  240.00000   10600000.0
# ..                  ...                  ...        ...          ...
# 83         @sanabutt660          Sanabutt660  414.22973   87650000.0
# 85   @real_umerkaraxhii  Real_@Umer KaraxHii  414.22973  121780000.0
# 91     @shaheer._.khan1         Shaheer khan  414.22973  199350000.0
# 92          @juttbahadr         Jutt bahader  414.22973  342600000.0
# 97   @laibakhanofficial           laiba khan  414.22973   59980000.0
#
#            Views     Country Date_Created    Year  Month
# 0   2.150000e+09    Pakistan   2018-03-18  2018.0    3.0
# 1   9.627400e+08    Pakistan   2018-09-22  2018.0    9.0
# 2   2.150000e+09    Pakistan   2018-07-20  2018.0    7.0
# 3   7.518600e+08    Pakistan   2016-06-25  2016.0    6.0
# 4   1.838600e+08    Pakistan   2017-03-06  2017.0    3.0
# ..           ...         ...          ...     ...    ...
# 83  1.000000e+09  2018-10-01          NaT     NaN    NaN
# 85  1.000000e+09  2017-10-02          NaT     NaN    NaN
# 91  1.000000e+09  2019-06-26          NaT     NaN    NaN
# 92  1.000000e+09  2018-12-14          NaT     NaN    NaN
# 97  1.000000e+09  2018-12-06          NaT     NaN    NaN
#
# [126 rows x 9 columns]

# %%
#data3.dropna(inplace=True)

# %%
data3['follow_per_vids'] = data3['Followers'] / data3['Videos']

# %%
data3['views_per_vids'] = data3['Views'] / data3['Videos']

# %%
data3
# Out:
#                 User_ID                 Name     Videos    Followers  \
# 0          @jannatmirza             J M ????  212.00000   13600000.0
# 1           @kanwal.135         Kanwalay????   39.00000   11600000.0
# 2      @ch.zulqarnain25  Zulqarnain Sikandar  573.00000   11400000.0
# 3        @alishbahanjum               Lishay  238.00000   11200000.0
# 4        @hoormahaveera       Hoor Mahaveera  240.00000   10600000.0
# ..                  ...                  ...        ...          ...
# 83         @sanabutt660          Sanabutt660  414.22973   87650000.0
# 85   @real_umerkaraxhii  Real_@Umer KaraxHii  414.22973  121780000.0
# 91     @shaheer._.khan1         Shaheer khan  414.22973  199350000.0
# 92          @juttbahadr         Jutt bahader  414.22973  342600000.0
# 97   @laibakhanofficial           laiba khan  414.22973   59980000.0
#
#            Views     Country Date_Created    Year  Month  follow_per_vids  \
# 0   2.150000e+09    Pakistan   2018-03-18  2018.0    3.0     64150.943396
# 1   9.627400e+08    Pakistan   2018-09-22  2018.0    9.0    297435.897436
# 2   2.150000e+09    Pakistan   2018-07-20  2018.0    7.0     19895.287958
# 3   7.518600e+08    Pakistan   2016-06-25  2016.0    6.0     47058.823529
# 4   1.838600e+08    Pakistan   2017-03-06  2017.0    3.0     44166.666667
# ..           ...         ...          ...     ...    ...              ...
# 83  1.000000e+09  2018-10-01          NaT     NaN    NaN    211597.559782
# 85  1.000000e+09  2017-10-02          NaT     NaN    NaN    293991.452713
# 91  1.000000e+09  2019-06-26          NaT     NaN    NaN    481254.689590
# 92  1.000000e+09  2018-12-14          NaT     NaN    NaN    827077.284442
# 97  1.000000e+09  2018-12-06          NaT     NaN    NaN    144798.877761
#
#     views_per_vids
# 0     1.014151e+07
# 1     2.468564e+07
# 2     3.752182e+06
# 3     3.159076e+06
# 4     7.660833e+05
# ..             ...
# 83    2.414119e+06
# 85    2.414119e+06
# 91    2.414119e+06
# 92    2.414119e+06
# 97    2.414119e+06
#
# [126 rows x 11 columns]

# %%
data3['Year'] = data3['Year'].astype(int)
data3['Month'] = data3['Month'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7024/1066947333.py in <module>
# ----> 1 data3['Year'] = data3['Year'].astype(int)
#       2 data3['Month'] = data3['Month'].astype(int)
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5804         else:
#    5805             # else, only a single dtype is given
# -> 5806             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5807             return self._constructor(new_data).__finalize__(self, method="astype")
#    5808
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     412
#     413     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 414         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     415
#     416     def convert(
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     325                     applied = b.apply(f, **kwargs)
#     326                 else:
# --> 327                     applied = getattr(b, f)(**kwargs)
#     328             except (TypeError, NotImplementedError):
#     329                 if not ignore_failures:
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     590         values = self.values
#     591
# --> 592         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     593
#     594         new_values = maybe_coerce_values(new_values)
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\dtypes\cast.py in astype_array_safe(values, dtype, copy, errors)
#    1298
#    1299     try:
# -> 1300         new_values = astype_array(values, dtype, copy=copy)
#    1301     except (ValueError, TypeError):
#    1302         # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\dtypes\cast.py in astype_array(values, dtype, copy)
#    1246
#    1247     else:
# -> 1248         values = astype_nansafe(values, dtype, copy=copy)
#    1249
#    1250     # in pandas we don't store numpy str dtypes, so convert to object
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1157
#    1158     elif np.issubdtype(arr.dtype, np.floating) and np.issubdtype(dtype, np.integer):
# -> 1159         return astype_float_to_int_nansafe(arr, dtype, copy)
#    1160
#    1161     elif is_object_dtype(arr):
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\dtypes\cast.py in astype_float_to_int_nansafe(values, dtype, copy)
#    1202     """
#    1203     if not np.isfinite(values).all():
# -> 1204         raise IntCastingNaNError(
#    1205             "Cannot convert non-finite values (NA or inf) to integer"
#    1206         )
#
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer

# %%
data1 = data3

# %% [markdown]
# # Preprocessed Dataset

# %%
data1.sample(20)
# Out:
#                     User_ID                  Name     Videos    Followers  \
# 1               @kanwal.135          Kanwalay????   39.00000   11600000.0
# 67            @ali_khanking         Ali Khan ????  414.22973  110230000.0
# 16       @mujtabalakhani123       mujtaba Lakhani  138.00000    5300000.0
# 28                 @umereee                  Umer  483.00000    4000000.0
# 20        @asadaliofficiall    Asad ali |????????  865.00000    5100000.0
# 84         @nabeelkhokhar66  nabeelkhokhar66 ????  743.00000    1900000.0
# 83             @sanabutt660           Sanabutt660  414.22973   87650000.0
# 24               @aliriaz84      Ali Riaz ♠️ ????  414.22973  182250000.0
# 30              @amnasabir2  A M N A  S A B I R ✅  177.00000    3700000.0
# 58           @salt_to_taste         Salt to taste  414.22973  172940000.0
# 91         @shaheer._.khan1          Shaheer khan  414.22973  199350000.0
# 12            @harrisali_01            Harris Ali  530.00000    5900000.0
# 14              @supari2222          Zafar supari  487.00000    5400000.0
# 2          @ch.zulqarnain25   Zulqarnain Sikandar  573.00000   11400000.0
# 94        @saqibsagheerkhan     Saqib sagheerkhan  436.00000    1800000.0
# 69         @arashayousafzai      Arasha Yousafzai  414.22973   17760000.0
# 77             @dimple_boys            dimpleboys  500.00000    2000000.0
# 34               @mehmood_j   ???? Mehmood J ????  427.00000    3600000.0
# 19                @rabeecak         Rabeecakashif  414.22973   96640000.0
# 9    @mehakmalikofficial578  Mehak Malik official  604.00000    7800000.0
#
#            Views     Country Date_Created    Year  Month  follow_per_vids  \
# 1   9.627400e+08    Pakistan   2018-09-22  2018.0    9.0    297435.897436
# 67  1.000000e+09  2019-01-13          NaT     NaN    NaN    266108.374384
# 16  6.316000e+08    Pakistan   2018-03-17  2018.0    3.0     38405.797101
# 28  3.377200e+08    Pakistan   2018-07-14  2018.0    7.0      8281.573499
# 20  3.833000e+08    Pakistan   2019-05-12  2019.0    5.0      5895.953757
# 84  2.403500e+08    Pakistan   2018-04-27  2018.0    4.0      2557.200538
# 83  1.000000e+09  2018-10-01          NaT     NaN    NaN    211597.559782
# 24  1.000000e+09  2019-11-25          NaT     NaN    NaN    439973.248948
# 30  1.709700e+08    Pakistan   2018-08-07  2018.0    8.0     20903.954802
# 58  1.000000e+09  2019-02-02          NaT     NaN    NaN    417497.797932
# 91  1.000000e+09  2019-06-26          NaT     NaN    NaN    481254.689590
# 12  8.015700e+08    Pakistan   2018-07-06  2018.0    7.0     11132.075472
# 14  3.934700e+08    Pakistan   2018-09-20  2018.0    9.0     11088.295688
# 2   2.150000e+09    Pakistan   2018-07-20  2018.0    7.0     19895.287958
# 94  9.634000e+07    Pakistan   2019-07-30  2019.0    7.0      4128.440367
# 69  1.000000e+09  2019-06-15          NaT     NaN    NaN     42874.759404
# 77  2.704600e+08    Pakistan   2019-06-04  2019.0    6.0      4000.000000
# 34  3.437700e+08    Pakistan   2019-04-22  2019.0    4.0      8430.913349
# 19  1.000000e+09  2018-08-31          NaT     NaN    NaN    233300.492611
# 9   1.940000e+09    Pakistan   2019-01-18  2019.0    1.0     12913.907285
#
#     views_per_vids
# 1     2.468564e+07
# 67    2.414119e+06
# 16    4.576812e+06
# 28    6.992133e+05
# 20    4.431214e+05
# 84    3.234859e+05
# 83    2.414119e+06
# 24    2.414119e+06
# 30    9.659322e+05
# 58    2.414119e+06
# 91    2.414119e+06
# 12    1.512396e+06
# 14    8.079466e+05
# 2     3.752182e+06
# 94    2.209633e+05
# 69    2.414119e+06
# 77    5.409200e+05
# 34    8.050820e+05
# 19    2.414119e+06
# 9     3.211921e+06

# %%
data1.shape
# Out:
# (126, 11)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 126 entries, 0 to 97
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   User_ID          126 non-null    object
#  1   Name             126 non-null    object
#  2   Videos           126 non-null    float64
#  3   Followers        126 non-null    float64
#  4   Views            126 non-null    float64
#  5   Country          126 non-null    object
#  6   Date_Created     74 non-null     datetime64[ns]
#  7   Year             74 non-null     float64
#  8   Month            74 non-null     float64
#  9   follow_per_vids  126 non-null    float64
#  10  views_per_vids   126 non-null    float64
# dtypes: datetime64[ns](1), float64(7), object(3)
# memory usage: 11.8+ KB

# %%
data1.describe()
# Out:
#            Videos     Followers         Views         Year      Month  \
# count  126.000000  1.260000e+02  1.260000e+02    74.000000  74.000000
# mean   414.229730  7.612746e+07  7.115826e+08  2018.297297   6.675676
# std    218.859756  1.100354e+08  4.485457e+08     0.735215   2.970670
# min      6.000000  1.800000e+06  2.203000e+07  2016.000000   1.000000
# 25%    328.500000  2.600000e+06  2.890450e+08  2018.000000   4.250000
# 50%    414.229730  6.900000e+06  8.046900e+08  2018.000000   7.000000
# 75%    447.500000  1.469500e+08  1.000000e+09  2019.000000   9.000000
# max    990.000000  4.141000e+08  2.150000e+09  2020.000000  12.000000
#
#        follow_per_vids  views_per_vids
# count       126.000000    1.260000e+02
# mean     197359.834800    3.148237e+06
# std      261166.012300    5.658647e+06
# min        2033.898305    3.611475e+04
# 25%        8318.908461    9.905194e+05
# 50%       42270.713035    2.414119e+06
# 75%      360423.639883    2.414119e+06
# max      999686.816951    3.459500e+07

# %%
plt.figure(figsize=(13,6))
ax = sns.countplot(x='Year', data = data1)
ax.bar_label(ax.containers[0])
plt.title('Year in which Accounts Created')
plt.show()

# %%
plt.figure(figsize=(13,6))
ax = sns.countplot(x='Month', data = data1)
ax.bar_label(ax.containers[0])
plt.title('Month in which Accounts Created')
plt.show()

# %%
def plot(xCol,title):
    plt.figure(figsize=(13,9))
    ax = sns.barplot(x=xCol, y='User_ID', data=data1.nlargest(15, xCol))
    ax.bar_label(ax.containers[0])
    plt.title(title)
    plt.show()

# %%
plot('Videos','Top 15 Most Video Uploaded on Tiktok Accounts')

# %%
plot('Followers','Top 15 Most Followed Tiktok Accounts')

# %%
plot('Views','Top 15 Most Viewed Tiktok Accounts')

# %%
plot('follow_per_vids','Top 15 Following per Videos')

# %%
plot('views_per_vids','Top 15 Views per Videos')

# %% [markdown]
# # End of Notebook
